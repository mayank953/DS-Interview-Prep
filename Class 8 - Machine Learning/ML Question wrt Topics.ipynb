# %% [markdown]
# ### Introduction to Machine Learning
#
# 1.  What is the difference between supervised and unsupervised learning?
# 2.  Explain the concept of reinforcement learning.
#
# ### Supervised Learning
#
# 1.  How does linear regression work?
# 2.  What are the assumptions of linear regression?
# 3.  Explain the difference between Ridge and Lasso regression.
# 4.  How would you evaluate a regression model?
# 5.  Describe logistic regression and its use cases.
# 6.  How does a decision tree algorithm work?
# 7.  What is the difference between a decision tree and a random forest?
# 8.  Explain the concept of Support Vector Machines (SVM).
# 9.  How does the k-nearest neighbors (k-NN) algorithm work?
# 10. Describe the Naive Bayes algorithm.
# 11. What metrics would you use to evaluate a classification model?
# 12. Explain the ROC curve and AUC.
#
# ### Unsupervised Learning
#
# 1.  What is k-means clustering and how does it work?
# 2.  Describe hierarchical clustering.
# 3.  How does the DBSCAN algorithm differ from k-means?
# 4.  What are the methods to evaluate clustering models?
# 5.  Explain Principal Component Analysis (PCA).
# 6.  What is t-SNE and when would you use it?
# 7.  Describe Linear Discriminant Analysis (LDA).
#
# ### Model Evaluation and Selection
#
# 1.  What is cross-validation and why is it important?
# 2.  Explain k-fold cross-validation.
# 3.  What is the bias-variance tradeoff?
# 4.  How do you diagnose if a model is overfitting or underfitting?
# 5.  Describe the process of grid search for model selection.
# 6.  How does random search differ from grid search?
#
# ### Feature Engineering
#
# 1.  What are some common methods for feature selection?
# 2.  Explain the difference between standardization and normalization.
# 3.  How do you handle categorical data in machine learning?
# 4.  What is one-hot encoding?
# 5.  When would you use label encoding?
# 6.  What is ordinal encoding and when is it used?
#
# ### Ensemble Methods
#
# 1.  What is bagging and how does it improve model performance?
# 2.  Describe the random forest algorithm.
# 3.  Explain the concept of boosting.
# 4.  What is AdaBoost and how does it work?
# 5.  How does gradient boosting differ from AdaBoost?
# 6.  Explain XGBoost and its advantages.
# 7.  What are LightGBM and CatBoost?
#
# ### Anomaly Detection
#
# 1.  What methods can you use for anomaly detection?
# 2.  Describe the isolation forest algorithm.
# 3.  How does one-class SVM work?
#
# ### Model Interpretability
#
# 1.  Why is model interpretability important?
# 2.  How do you determine feature importance in a model?
#
#
# ### Specialized Topics
#
# 1.  What are the components of a time series?
# 2.  Describe the ARIMA model for time series analysis.
# 3.  What is exponential smoothing?
# 4.  Explain collaborative filtering in recommender systems.
# 5.  How does content-based filtering work?
# 6.  What are hybrid recommender systems?

# %% [markdown]
# Fundamentals of Machine Learning
# --------------------------------
#
# [](https://github.com/vishalsingh17/iNeuronMLQuestions/blob/main/1.Fundamentals%20of%20ML.md#fundamentals-of-machine-learning)
#
# Q1. What is machine learning?
#
# Q2. Why do we use machine learning?
#
# Q3. How many types of machine learning systems do we have?
#
# Q4. What is the difference between supervised and unsupervised learning system?
#
# Q5. What is semi-supervised learning system?
#
# Q6. What is reinforcement learning?
#
# Q7. What is batch and online learning?
#
# Q8. What is the difference between instance-based and model-based learning system?
#
# Q9. What are the challenges faced by the machine learning systems?
#
# Q10. What is out-of-core learning?
#
# Q11. If a company wants to develop a system which can be used if a mail is ham or spam mail, then which type of learning system should be used?
#
# Q12. If a company wants to predict a model-based learning system which can be used to predict the cost of a car based on certain parameters, then which type of learning system should be used?
#
# Q13. If a company wants to train a robot which has the ability to take decisions based on the current state of the robot, then which type of learning system should be used?

# %% [markdown]
# Q31. What is meant by regression?
#
# Q32. What is meant by linear regression? Modelling technique to predict continuous values where the independent features follow a linear trend
#
# Q33. Write a python function that take an input value, weight and bais as an input and returns the returns the prediction.
#
# Q34. What is normal equation?
#
# Q35 What is an error?
#
# Q36. What is the difference between error and cost function?
#
# Q37. What is gradient descent?
#
# Q38. What is random initialization in gradient descent?
#
# Q39. What is the role of learning rate?
#
# Q40. What will happen if the learning rate is too less?
#
# Q41 What will happen if the learning rate is too large?
#
# Q42. What is local and global minima?
#
# Q43. What is batch gradient descent?
#
# Q44. What is gradient ascent?
#
# Q45. What is stochastic gradient descent? stochastic - random and SGD - we are updting gradients for 1 record at a time
#
# Q46. What is mini batch gradient descent?
